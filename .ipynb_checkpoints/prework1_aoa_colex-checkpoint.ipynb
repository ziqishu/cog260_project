# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from itertools import product

pd.options.mode.chained_assignment = None

# %% [markdown]
# First, we generate df with all the dataset and w_age_df as a subset of df that contains notnull value for age_of_acquisition.

# %%
df = pd.read_csv("data/df_all_raw.csv")
df.columns = list(map(str.lower, df.columns))
df = df.drop(columns=['dataset_id', 'form_id', 'form', 'gloss_in_source', 'iso639p3code', 'mrc_word', 'kucera_francis_frequency'])
w_age_df = df[df['age_of_acquisition'].notnull()]

print(f"Number of rows in the original df: {df.shape[0]}")
num_languages = df['variety'].nunique()
print(f"Number of unique languages in the original df: {num_languages}")

print("=====================================================================================================")

print(f"Number of rows in the df with age of acquisition: {w_age_df.shape[0]}")
num_languages = w_age_df['variety'].nunique()
print(f"Number of unique languages in the df with age of acquisition: {num_languages}")
age_of_acquisition_per_concept = w_age_df.groupby('concepticon_gloss')['age_of_acquisition'].first().reset_index()
print('Number of concepts in the df with age of acquisition:', age_of_acquisition_per_concept.shape[0])
# Out:
# C:\Users\Ziqi\AppData\Local\Temp\ipykernel_22824\955783045.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/df_all_raw.csv")
# Number of rows in the original df: 1390594
# Number of unique languages in the original df: 3050
# =====================================================================================================
# Number of rows in the df with age of acquisition: 330160
# Number of unique languages in the df with age of acquisition: 3016
# Number of concepts in the df with age of acquisition: 486

# %% [markdown]
# Second, we calculate colexification count.

# %%
def per_lang_colexification(curr_df):
    """
    Calculate the colexification frequency of pairs of concepts present in the current language.
    """
    all_combos_dict = {}
    # We iterate through each row, which has the concepts associated with a specific word
    for i, row in curr_df.iterrows():
        # Get the current set of concepts
        a = row['concepticon_gloss']
        # Create all possible unique combinations of concepts, where each pair is alphabetically sorted
        combos = list(set(map(lambda x: tuple(sorted(x)), product(a, a))))
        # Ensure the concepts in the pair are not identical
        combos = [combo for combo in combos if combo[0] != combo[1]]
        # Add counts for a pair of combinations being colexified
        for combo in combos:
            if combo in all_combos_dict:
                all_combos_dict[combo] += 1
            else:
                all_combos_dict[combo] = 1

    # Create a DataFrame out of our dictionary and return the colexification counts for two concepts
    tmp = pd.DataFrame.from_dict(all_combos_dict, "index").reset_index()
    per_lang = pd.DataFrame(tmp['index'].tolist(), columns=['concept_1', "concept_2"])
    per_lang['colexification_count'] = tmp[0]
    return per_lang

def main():
    all_dfs = []
    for variety in tqdm(w_age_df['variety'].unique()):
        sub = w_age_df[w_age_df['variety'] == variety]
        agg = sub.groupby("clics_form")[['concepticon_gloss', 'concepticon_id']].agg(list)
        agg['num_concepts'] = agg['concepticon_gloss'].apply(lambda x: len(set(x)))
        colex = agg[agg['num_concepts']>1]
        colex['concepticon_gloss'] = colex['concepticon_gloss'].apply(lambda x: sorted(list(set(x))))
        # We skip any language where no concepts are colexified
        if colex.shape[0] == 0:
            continue
        curr_df = per_lang_colexification(colex)
        all_dfs.append(curr_df)
    mega = pd.concat(all_dfs)
    colex_counts = mega.groupby(["concept_1", "concept_2"]).sum().reset_index()
    return colex_counts

# %%
colex_counts = main()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 3016/3016 [02:22<00:00, 21.19it/s]

# %%
colex_counts.sort_values(by='colexification_count')
colex_with_age = pd.merge(colex_counts, age_of_acquisition_per_concept, left_on='concept_1', right_on='concepticon_gloss')
colex_with_age = pd.merge(colex_with_age, age_of_acquisition_per_concept, left_on='concept_2', right_on='concepticon_gloss', suffixes=('_1', '_2'))
merged_data = colex_counts.merge(
    age_of_acquisition_per_concept, left_on='concept_1', right_on='concepticon_gloss', how='left'
).merge(
    age_of_acquisition_per_concept, left_on='concept_2', right_on='concepticon_gloss', how='left', suffixes=('_1', '_2')
)

merged_data['avg_age_acquisition'] = merged_data[['age_of_acquisition_1', 'age_of_acquisition_2']].mean(axis=1)
merged_data['age_acquisition_diff'] = abs(merged_data['age_of_acquisition_1'] - merged_data['age_of_acquisition_2'])
merged_data = merged_data.drop(columns=['age_of_acquisition_1', 'age_of_acquisition_2', 'concepticon_gloss_1', 'concepticon_gloss_2', 'avg_age_acquisition'])
merged_data.head()
# Out:
#    concept_1 concept_2  colexification_count  age_acquisition_diff
# 0   ADULTERY    DECEIT                     1                  64.0
# 1   ADULTERY      WALK                     1                 377.0
# 2  AFTERNOON    AUTUMN                     1                   3.0
# 3  AFTERNOON      COLD                     1                  98.0
# 4  AFTERNOON   EVENING                    17                  22.0

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3662 entries, 0 to 3661
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   concept_1             3662 non-null   object
#  1   concept_2             3662 non-null   object
#  2   colexification_count  3662 non-null   int64
#  3   age_acquisition_diff  3662 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 114.6+ KB

# %% [markdown]
# Third, we extract the association feature from the SWOW dataset.

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

adf = pd.read_csv("data/swow_assoc.csv")
def find_assoc(assoc, word):
    if word in assoc.index:
        return assoc.loc[word, 'counts']
    else:
        return 0
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [12], line 1
# ----> 1 import spacy
#       2 nlp = spacy.load("en_core_web_sm")
#       4 adf = pd.read_csv("data/swow_assoc.csv")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\__init__.py:6
#       3 import sys
#       5 # set library-specific custom warning handling before doing anything else
# ----> 6 from .errors import setup_default_warnings
#       8 setup_default_warnings()  # noqa: E402
#      10 # These are imported as part of the API
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\errors.py:2
#       1 import warnings
# ----> 2 from .compat import Literal
#       5 class ErrorsWithCodes(type):
#       6     def __getattribute__(self, code):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\compat.py:3
#       1 """Helpers for Python and platform compatibility."""
#       2 import sys
# ----> 3 from thinc.util import copy_array
#       5 try:
#       6     import cPickle as pickle
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\thinc\__init__.py:5
#       2 import numpy
#       4 from .about import __version__
# ----> 5 from .config import registry
#       8 # fmt: off
#       9 __all__ = [
#      10     "registry",
#      11     "__version__",
#      12 ]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\thinc\config.py:2
#       1 import catalogue
# ----> 2 import confection
#       3 from confection import Config, ConfigValidationError, Promise, VARIABLE_RE
#       4 from .types import Decorator
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\confection\__init__.py:10
#       8 from configparser import ParsingError
#       9 from pathlib import Path
# ---> 10 from pydantic import BaseModel, create_model, ValidationError, Extra
#      11 from pydantic.main import ModelMetaclass
#      12 from pydantic.fields import ModelField
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pydantic\__init__.py:2, in init pydantic.__init__()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pydantic\dataclasses.py:43, in init pydantic.dataclasses()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pydantic\error_wrappers.py:4, in init pydantic.error_wrappers()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pydantic\json.py:13, in init pydantic.json()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pydantic\networks.py:30, in init pydantic.networks()
#
# ImportError: cannot import name errors

# %%
import spacy
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 import spacy
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\__init__.py:6
#       3 import sys
#       5 # set library-specific custom warning handling before doing anything else
# ----> 6 from .errors import setup_default_warnings
#       8 setup_default_warnings()  # noqa: E402
#      10 # These are imported as part of the API
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\errors.py:2
#       1 import warnings
# ----> 2 from .compat import Literal
#       5 class ErrorsWithCodes(type):
#       6     def __getattribute__(self, code):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\compat.py:3
#       1 """Helpers for Python and platform compatibility."""
#       2 import sys
# ----> 3 from thinc.util import copy_array
#       5 try:
#       6     import cPickle as pickle
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\thinc\__init__.py:5
#       2 import numpy
#       4 from .about import __version__
# ----> 5 from .config import registry
#       8 # fmt: off
#       9 __all__ = [
#      10     "registry",
#      11     "__version__",
#      12 ]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\thinc\config.py:2
#       1 import catalogue
# ----> 2 import confection
#       3 from confection import Config, ConfigValidationError, Promise, VARIABLE_RE
#       4 from .types import Decorator
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\confection\__init__.py:10
#       8 from configparser import ParsingError
#       9 from pathlib import Path
# ---> 10 from pydantic import BaseModel, create_model, ValidationError, Extra
#      11 from pydantic.main import ModelMetaclass
#      12 from pydantic.fields import ModelField
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pydantic\__init__.py:2, in init pydantic.__init__()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pydantic\dataclasses.py:43, in init pydantic.dataclasses()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pydantic\error_wrappers.py:4, in init pydantic.error_wrappers()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pydantic\json.py:13, in init pydantic.json()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pydantic\networks.py:30, in init pydantic.networks()
#
# ImportError: cannot import name errors

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

for index, row in df.iterrows():
    
    concept_1_lower = str(nlp(row['concept_1'].lower()))
    concept_2_lower = str(nlp(row['concept_2'].lower()))

    if concept_1_lower in adf['cue'].values:
        adf_temp = adf[adf['cue'] == concept_1_lower]
        all_assoc_temp = dict(Counter(adf_temp[['R1', 'R2', 'R3']].values.flatten()))
        assoc_temp = pd.DataFrame.from_dict(all_assoc_temp, orient="index").sort_values(by=0, ascending=False).rename(columns={0: "counts"})
        df.loc[index, 'assoc'] = find_assoc(assoc_temp, concept_2_lower)       
    elif concept_2_lower in adf['cue'].values:
        adf_temp = adf[adf['cue'] == concept_2_lower]
        all_assoc_temp = dict(Counter(adf_temp[['R1', 'R2', 'R3']].values.flatten()))
        assoc_temp = pd.DataFrame.from_dict(all_assoc_temp, orient="index").sort_values(by=0, ascending=False).rename(columns={0: "counts"})
        df.loc[index, 'assoc'] = find_assoc(assoc_temp, concept_1_lower)
    else:
        # set the value to NaN
        df.loc[index, 'assoc'] = np.nan

# %%
df = pd.read_csv("aoa_crt_sim_assoc_target.csv")
df.head()
# Out:
#    concept_1 concept_2  colexification_count concepticon_gloss_1  \
# 0  AFTERNOON    AUTUMN                     1           AFTERNOON
# 1  AFTERNOON      COLD                     1           AFTERNOON
# 2  AFTERNOON   EVENING                    17           AFTERNOON
# 3  AFTERNOON      LOOK                     1           AFTERNOON
# 4  AFTERNOON     LUNCH                     2           AFTERNOON
#
#    age_of_acquisition_1 concepticon_gloss_2  age_of_acquisition_2  \
# 0                 281.0              AUTUMN                 278.0
# 1                 281.0                COLD                 183.0
# 2                 281.0             EVENING                 303.0
# 3                 281.0                LOOK                 225.0
# 4                 281.0               LUNCH                 275.0
#
#    avg_age_acquisition  age_acquisition_diff  Word2Vec_similarity  \
# 0                279.5                   3.0             0.609916
# 1                232.0                  98.0             0.470634
# 2                292.0                  22.0             0.756927
# 3                253.0                  56.0             0.465106
# 4                278.0                   6.0             0.684256
#
#    association  concreteness_diff  concreteness_1  concreteness_2  assoc  \
# 0          1.0               15.0           406.0           421.0    0.0
# 1          1.0               51.0           406.0           457.0    0.0
# 2         17.0               33.0           406.0           439.0   15.0
# 3          1.0               30.0           406.0           376.0    0.0
# 4          2.0              146.0           406.0           552.0   11.0
#
#    target
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1

# %%
w_age_df = df

# %% [markdown]
# This indicates that despite the substantial reduction in the number of rows in w_age_df compared to df, it still retains considerable potential for cross-linguistic analysis.

# %%
import matplotlib.pyplot as plt

plt.hist(w_age_df['age_of_acquisition'], bins=20, edgecolor='black')
plt.title('Distribution of Age of Acquisition')
plt.xlabel('Age of Acquisition')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# By observing the data, we found that one concept will only have one age of acquisition value across all languages.
# Let's check if this is true.

# %%
age_acquisition_std = w_age_df.groupby('concepticon_gloss')['age_of_acquisition'].std()

if age_acquisition_std.max() == 0:
    print("There are no age of acquisition values that vary for a given concepticon gloss.")
else:
    print("There are age of acquisition values that vary for a given concepticon gloss.")
# Out:
# There are no age of acquisition values that vary for a given concepticon gloss.

# %% [markdown]
# Therefore, any concept will only have one age of acquisition across languages. Hence, we create a dataframe to show the age of acquisition of each concept

# %%
age_of_acquisition_per_concept = w_age_df.groupby('concepticon_gloss')['age_of_acquisition'].first().reset_index()
age_of_acquisition_per_concept
# Out:
#     concepticon_gloss  age_of_acquisition
# 0            ADULTERY               583.0
# 1           AFTERNOON               281.0
# 2                 AGE               258.0
# 3              ANIMAL               222.0
# 4               ANKLE               264.0
# ..                ...                 ...
# 481              WORM               253.0
# 482             WOUND               372.0
# 483             WRONG               244.0
# 484              YARD               308.0
# 485              YEAR               269.0
#
# [486 rows x 2 columns]

# %% [markdown]
# Then, we will generate the colexification counts of pairs of concepts across all language in w_age_df

# %%
def per_lang_colexification(curr_df):
    """
    Calculate the colexification frequency of pairs of concepts present in the current language.
    """
    all_combos_dict = {}
    # We iterate through each row, which has the concepts associated with a specific word
    for i, row in curr_df.iterrows():
        # Get the current set of concepts
        a = row['concepticon_gloss']
        # Create all possible unique combinations of concepts, where each pair is alphabetically sorted
        combos = list(set(map(lambda x: tuple(sorted(x)), product(a, a))))
        # Ensure the concepts in the pair are not identical
        combos = [combo for combo in combos if combo[0] != combo[1]]
        # Add counts for a pair of combinations being colexified
        for combo in combos:
            if combo in all_combos_dict:
                all_combos_dict[combo] += 1
            else:
                all_combos_dict[combo] = 1

    # Create a DataFrame out of our dictionary and return the colexification counts for two concepts
    tmp = pd.DataFrame.from_dict(all_combos_dict, "index").reset_index()
    per_lang = pd.DataFrame(tmp['index'].tolist(), columns=['concept_1', "concept_2"])
    per_lang['colexification_count'] = tmp[0]
    return per_lang

# %%
def main():
    all_dfs = []
    for variety in tqdm(w_age_df['variety'].unique()):
        sub = w_age_df[w_age_df['variety'] == variety]
        agg = sub.groupby("clics_form")[['concepticon_gloss', 'concepticon_id']].agg(list)
        agg['num_concepts'] = agg['concepticon_gloss'].apply(lambda x: len(set(x)))
        colex = agg[agg['num_concepts']>1]
        colex['concepticon_gloss'] = colex['concepticon_gloss'].apply(lambda x: sorted(list(set(x))))
        # We skip any language where no concepts are colexified
        if colex.shape[0] == 0:
            continue
        curr_df = per_lang_colexification(colex)
        all_dfs.append(curr_df)
    mega = pd.concat(all_dfs)
    colex_counts = mega.groupby(["concept_1", "concept_2"]).sum().reset_index()
    return colex_counts

# %%
colex_counts = main()
# Out:
# 100%|██████████| 3016/3016 [01:40<00:00, 29.93it/s]

# %%
colex_counts.sort_values(by='colexification_count')
# Out:
#              concept_1         concept_2  colexification_count
# 0             ADULTERY            DECEIT                     1
# 2287            GROUND              ROPE                     1
# 2288            GROUND              SAND                     1
# 2289            GROUND           SCRATCH                     1
# 2290            GROUND            SPEECH                     1
# ...                ...               ...                   ...
# 2470              HILL          MOUNTAIN                   142
# 2957             MONEY            SILVER                   151
# 2892  MALE (OF ANIMAL)  MALE (OF PERSON)                   159
# 1638      EARTH (SOIL)              LAND                   187
# 1260           COUNTRY              LAND                   226
#
# [3662 rows x 3 columns]

# %%
import pandas as pd
import numpy as np
from scipy.stats import pearsonr

# %%
colex_with_age = pd.merge(colex_counts, age_of_acquisition_per_concept, left_on='concept_1', right_on='concepticon_gloss')
colex_with_age = pd.merge(colex_with_age, age_of_acquisition_per_concept, left_on='concept_2', right_on='concepticon_gloss', suffixes=('_1', '_2'))
colex_with_age
# Out:
#                     concept_1 concept_2  colexification_count  \
# 0                    ADULTERY    DECEIT                     1
# 1                       BOAST    DECEIT                     1
# 2                    ADULTERY      WALK                     1
# 3                      ANSWER      WALK                     1
# 4                        AUNT      WALK                     1
# ...                       ...       ...                   ...
# 3657  OIL (ORGANIC SUBSTANCE)     OLIVE                     1
# 3658  OIL (ORGANIC SUBSTANCE)     SAUCE                     1
# 3659                     PLOT   WHISPER                     1
# 3660                   SILVER      SOAP                     1
# 3661          SMOKE (EXHAUST)     STEAM                     6
#
#           concepticon_gloss_1  age_of_acquisition_1 concepticon_gloss_2  \
# 0                    ADULTERY                 583.0              DECEIT
# 1                       BOAST                 378.0              DECEIT
# 2                    ADULTERY                 583.0                WALK
# 3                      ANSWER                 294.0                WALK
# 4                        AUNT                 233.0                WALK
# ...                       ...                   ...                 ...
# 3657  OIL (ORGANIC SUBSTANCE)                 303.0               OLIVE
# 3658  OIL (ORGANIC SUBSTANCE)                 303.0               SAUCE
# 3659                     PLOT                 422.0             WHISPER
# 3660                   SILVER                 317.0                SOAP
# 3661          SMOKE (EXHAUST)                 228.0               STEAM
#
#       age_of_acquisition_2
# 0                    519.0
# 1                    519.0
# 2                    206.0
# 3                    206.0
# 4                    206.0
# ...                    ...
# 3657                 458.0
# 3658                 258.0
# 3659                 256.0
# 3660                 222.0
# 3661                 308.0
#
# [3662 rows x 7 columns]

# %%
merged_data = colex_counts.merge(
    age_of_acquisition_per_concept, left_on='concept_1', right_on='concepticon_gloss', how='left'
).merge(
    age_of_acquisition_per_concept, left_on='concept_2', right_on='concepticon_gloss', how='left', suffixes=('_1', '_2')
)

merged_data['avg_age_acquisition'] = merged_data[['age_of_acquisition_1', 'age_of_acquisition_2']].mean(axis=1)
merged_data['age_acquisition_diff'] = abs(merged_data['age_of_acquisition_1'] - merged_data['age_of_acquisition_2'])

# %%
merged_data.head()
#save the merged data to csv
merged_data.to_csv('merged_data.csv', index=False)

# %%
#get the size of merged_data
merged_data_rank = merged_data.sort_values(by='colexification_count', ascending=False)
merged_data1 = merged_data_rank[:1220]
merged_data2 = merged_data_rank[1220:2440]
merged_data3 = merged_data_rank[2440:]

# %%
merged_data1
# Out:
#              concept_1         concept_2  colexification_count  \
# 1260           COUNTRY              LAND                   226
# 1638      EARTH (SOIL)              LAND                   187
# 2892  MALE (OF ANIMAL)  MALE (OF PERSON)                   159
# 2957             MONEY            SILVER                   151
# 2470              HILL          MOUNTAIN                   142
# ...                ...               ...                   ...
# 2203       GRANDMOTHER              HIDE                     1
# 2204       GRANDMOTHER    HORN (ANATOMY)                     1
# 2205       GRANDMOTHER              LOOK                     1
# 3616               TRY              TURN                     1
# 2207       GRANDMOTHER             NIGHT                     1
#
#      concepticon_gloss_1  age_of_acquisition_1 concepticon_gloss_2  \
# 1260             COUNTRY                 329.0                LAND
# 1638        EARTH (SOIL)                 317.0                LAND
# 2892    MALE (OF ANIMAL)                 383.0    MALE (OF PERSON)
# 2957               MONEY                 247.0              SILVER
# 2470                HILL                 256.0            MOUNTAIN
# ...                  ...                   ...                 ...
# 2203         GRANDMOTHER                 208.0                HIDE
# 2204         GRANDMOTHER                 208.0      HORN (ANATOMY)
# 2205         GRANDMOTHER                 208.0                LOOK
# 3616                 TRY                 229.0                TURN
# 2207         GRANDMOTHER                 208.0               NIGHT
#
#       age_of_acquisition_2  avg_age_acquisition  age_acquisition_diff
# 1260                 286.0                307.5                  43.0
# 1638                 286.0                301.5                  31.0
# 2892                 383.0                383.0                   0.0
# 2957                 317.0                282.0                  70.0
# 2470                 283.0                269.5                  27.0
# ...                    ...                  ...                   ...
# 2203                 256.0                232.0                  48.0
# 2204                 308.0                258.0                 100.0
# 2205                 225.0                216.5                  17.0
# 3616                 233.0                231.0                   4.0
# 2207                 222.0                215.0                  14.0
#
# [1220 rows x 9 columns]

# %%
merged_data3
# Out:
#      concept_1    concept_2  colexification_count concepticon_gloss_1  \
# 821    BROTHER       SECOND                     1             BROTHER
# 807     BRIDGE       THREAD                     1              BRIDGE
# 810    BROTHER         BUSH                     1             BROTHER
# 812    BROTHER       FAMILY                     1             BROTHER
# 813    BROTHER  GRANDFATHER                     1             BROTHER
# ...        ...          ...                   ...                 ...
# 1411      DEER       FOREST                     1                DEER
# 1412      DEER         HARE                     1                DEER
# 1413      DEER          HAY                     1                DEER
# 1414      DEER         HEAD                     1                DEER
# 3661     WOUND         YEAR                     1               WOUND
#
#       age_of_acquisition_1 concepticon_gloss_2  age_of_acquisition_2  \
# 821                  219.0              SECOND                 289.0
# 807                  289.0              THREAD                 267.0
# 810                  219.0                BUSH                 256.0
# 812                  219.0              FAMILY                 280.0
# 813                  219.0         GRANDFATHER                 214.0
# ...                    ...                 ...                   ...
# 1411                 281.0              FOREST                 297.0
# 1412                 281.0                HARE                 281.0
# 1413                 281.0                 HAY                 297.0
# 1414                 281.0                HEAD                 181.0
# 3661                 372.0                YEAR                 269.0
#
#       avg_age_acquisition  age_acquisition_diff
# 821                 254.0                  70.0
# 807                 278.0                  22.0
# 810                 237.5                  37.0
# 812                 249.5                  61.0
# 813                 216.5                   5.0
# ...                   ...                   ...
# 1411                289.0                  16.0
# 1412                281.0                   0.0
# 1413                289.0                  16.0
# 1414                231.0                 100.0
# 3661                320.5                 103.0
#
# [1222 rows x 9 columns]

# %%
for data in [merged_data1, merged_data2, merged_data3]:
    print(pearsonr(data['age_acquisition_diff'], data['colexification_count']))
    print(pearsonr(data['age_acquisition_diff'], np.log(data['colexification_count'])))
    print(spearmanr(data['age_acquisition_diff'], data['colexification_count']))

    plt.figure(figsize=(10, 6))
    plt.scatter(data['age_acquisition_diff'], data['colexification_count'])
    plt.xlabel('Age of Acquisition Difference')
    plt.ylabel('Colexification Count')
    plt.title('Age of Acquisition Difference vs. Colexification Count')
    plt.show()

    plt.figure(figsize=(10, 6))

    # plot the y as the log transformation of the colexification count
    plt.scatter(data['age_acquisition_diff'], np.log(data['colexification_count']))
    # plt.scatter(merged_data['age_acquisition_diff'], merged_data['colexification_count'])
    plt.xlabel('Age of Acquisition Difference')
    plt.ylabel('Log of Colexification Count')
    plt.title('Age of Acquisition Difference vs. Log of Colexification Count')
    plt.show()
# Out:
# PearsonRResult(statistic=-0.05291089609542794, pvalue=0.06467501140202825)
# PearsonRResult(statistic=-0.04355569443685616, pvalue=0.12838608579373878)
# SpearmanrResult(correlation=-0.025471946538645585, pvalue=0.37404120377437833)
# c:\Users\Ziqi\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_stats_py.py:4427: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# c:\Users\Ziqi\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_stats_py.py:4881: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# PearsonRResult(statistic=nan, pvalue=nan)
# PearsonRResult(statistic=nan, pvalue=nan)
# SpearmanrResult(correlation=nan, pvalue=nan)
# PearsonRResult(statistic=nan, pvalue=nan)
# PearsonRResult(statistic=nan, pvalue=nan)
# SpearmanrResult(correlation=nan, pvalue=nan)

# %%
import matplotlib.pyplot as plt

#plot merged_data['avg_age_acquisition'] and merged_data['colexification_count']
plt.figure(figsize=(10, 6))
plt.scatter(merged_data['avg_age_acquisition'], merged_data['colexification_count'])
plt.xlabel('Average Age of Acquisition')
plt.ylabel('Colexification Count')
plt.title('Average Age of Acquisition vs. Colexification Count')
plt.show()

# %%
correlation, p_value = pearsonr(merged_data['avg_age_acquisition'], merged_data['colexification_count'])

print("Between avg_age_acquisition and colex_count:")
print(f"Correlation coefficient: {correlation}")
print(f"P-value: {p_value}")

# Check the significance of the correlation
if p_value < 0.05:
    print("The correlation between avg_age_acquisition and colex_count is statistically significant.")
else:
    print("The correlation between avg_age_acquisition and colex_count is not statistically significant.")
# Out:
# Between avg_age_acquisition and colex_count:
# Correlation coefficient: -0.005479294922721829
# P-value: 0.7402926185116339
# The correlation between avg_age_acquisition and colex_count is not statistically significant.

# %%
plt.figure(figsize=(10, 6))
plt.scatter(merged_data['age_acquisition_diff'], merged_data['colexification_count'])
plt.xlabel('Age of Acquisition Difference')
plt.ylabel('Colexification Count')
plt.title('Age of Acquisition Difference vs. Colexification Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))

# plot the y as the log transformation of the colexification count
plt.scatter(merged_data['age_acquisition_diff'], np.log(merged_data['colexification_count']))
# plt.scatter(merged_data['age_acquisition_diff'], merged_data['colexification_count'])
plt.xlabel('Age of Acquisition Difference')
plt.ylabel('Log of Colexification Count')
plt.title('Age of Acquisition Difference vs. Log of Colexification Count')
plt.show()

# %%
correlation, p_value = pearsonr(merged_data['age_acquisition_diff'], merged_data['colexification_count'])

print("Between avg_age_acquisition and colex_count:")
print(f"Correlation coefficient: {correlation}")
print(f"P-value: {p_value}")

# Check the significance of the correlation
if p_value < 0.05:
    print("The correlation between avg_age_acquisition and colex_count is statistically significant.")
else:
    print("The correlation between avg_age_acquisition and colex_count is not statistically significant.")
# Out:
# Between avg_age_acquisition and colex_count:
# Correlation coefficient: -0.05639734655869011
# P-value: 0.0006392089478462272
# The correlation between avg_age_acquisition and colex_count is statistically significant.

# %%
from scipy.stats import spearmanr
# spearmanr(merged_data['age_acquisition_diff'], merged_data['colexification_count'])
spearmanr(merged_data['age_acquisition_diff'], np.log(merged_data['colexification_count']))
# np.log(merged_data['colexification_count'])
# Out:
# SpearmanrResult(correlation=-0.10015610299991724, pvalue=1.2468401919693159e-09)

# %%
spearmanr(merged_data['age_acquisition_diff'], merged_data['colexification_count'])
# Out:
# SpearmanrResult(correlation=-0.10015610299991724, pvalue=1.2468401919693159e-09)

# %% [markdown]
# # Statistical test - take various vairables to compare the effects
