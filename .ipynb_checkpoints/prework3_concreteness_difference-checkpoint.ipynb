# %%
import pandas as pd

# %%
pd.options.mode.chained_assignment = None

# %%
df = pd.read_csv("data/aoa_assoc_word2vec_colex.csv")

# %%
df_colex = pd.read_csv("data/df_all_raw.csv")
# Out:
# C:\Users\Ziqi\AppData\Local\Temp\ipykernel_10172\3461934554.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_colex = pd.read_csv("data/df_all_raw.csv")

# %%
df_colex.columns = list(map(str.lower, df_colex.columns))
df_colex = df_colex.drop(columns=['dataset_id', 'form_id', 'form', 'gloss_in_source', 'iso639p3code', 'mrc_word', 'kucera_francis_frequency'])

# %%
df_colex.head()
# Out:
#   clics_form  concepticon_id concepticon_gloss ontological_category  \
# 0        san            1369              GOLD         Person/Thing
# 1        san            1369              GOLD         Person/Thing
# 2        san            1369              GOLD         Person/Thing
# 3        san            1369              GOLD         Person/Thing
# 4        san            1369              GOLD         Person/Thing
#
#                  semantic_field          variety glottocode macroarea  \
# 0  Basic actions and technology     Bugun Bichom   bich1234       NaN
# 1  Basic actions and technology      Bugun Kaspi   kasp1234       NaN
# 2  Basic actions and technology    Bugun Namphri   namp1239       NaN
# 3  Basic actions and technology  Bugun Singchung   sing1271       NaN
# 4  Basic actions and technology     Bugun Wangho   wang1301       NaN
#
#          family  latitude  longitude  age_of_acquisition  concreteness  \
# 0  Sino-Tibetan       NaN        NaN                 NaN         576.0
# 1  Sino-Tibetan       NaN        NaN                 NaN         576.0
# 2  Sino-Tibetan       NaN        NaN                 NaN         576.0
# 3  Sino-Tibetan       NaN        NaN                 NaN         576.0
# 4  Sino-Tibetan       NaN        NaN                 NaN         576.0
#
#    familiarity  imagability
# 0        550.0        594.0
# 1        550.0        594.0
# 2        550.0        594.0
# 3        550.0        594.0
# 4        550.0        594.0

# %%
df_selected_columns = df_colex[["concreteness", "concepticon_gloss", "concepticon_id"]]

# %%
df.head()
# Out:
#    Unnamed: 0  concept_1 concept_2  colexification_count  \
# 0           2  AFTERNOON    AUTUMN                     1
# 1           3  AFTERNOON      COLD                     1
# 2           4  AFTERNOON   EVENING                    17
# 3           5  AFTERNOON      LOOK                     1
# 4           6  AFTERNOON     LUNCH                     2
#
#    age_acquisition_diff  assoc  Word2Vec_similarity
# 0                   3.0    0.0             0.609916
# 1                  98.0    0.0             0.470634
# 2                  22.0   15.0             0.756927
# 3                  56.0    0.0             0.465106
# 4                   6.0   11.0             0.684256

# %%
df_selected_columns.head()
# Out:
#    concreteness concepticon_gloss  concepticon_id
# 0         576.0              GOLD            1369
# 1         576.0              GOLD            1369
# 2         576.0              GOLD            1369
# 3         576.0              GOLD            1369
# 4         576.0              GOLD            1369

# %%
concept1 = df["concepticon_1"]
concept2 = df["concepticon_2"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'concepticon_gloss_1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 concept1 = df["concepticon_gloss_1"]
#       2 concept2 = df["concepticon_gloss_2"]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'concepticon_gloss_1'

# %%
my_dict = dict(zip(df_selected_columns["concepticon_gloss"], df_selected_columns["concreteness"]))
my_dict["GOLD"]
# Out:
# 576.0

# %%
concrete_diff = []
concrete_1 = []
concrete_2 = []
for c1, c2 in zip(concept1, concept2):
    concrete1 = my_dict[c1]
    concrete2 = my_dict[c2]
    val = abs(concrete1 - concrete2)
    concrete_1.append(concrete1)
    concrete_2.append(concrete2)
    concrete_diff.append(val)

# %%
df['concreteness_diff'] = concrete_diff
df['concreteness_1'] = concrete_1
df['concreteness_2'] = concrete_2

# %%
#df.to_csv('updated_merged_data.csv', index=False)

# %%
df2 = df[df['colexification_count'] != 1]

# %%
df2.head()
# Out:
#    concept_1 concept_2  colexification_count concepticon_gloss_1  \
# 4  AFTERNOON   EVENING                    17           AFTERNOON
# 6  AFTERNOON     LUNCH                     2           AFTERNOON
# 7  AFTERNOON     NIGHT                     3           AFTERNOON
# 8  AFTERNOON       PIG                     2           AFTERNOON
# 9  AFTERNOON       SUN                     2           AFTERNOON
#
#    age_of_acquisition_1 concepticon_gloss_2  age_of_acquisition_2  \
# 4                 281.0             EVENING                 303.0
# 6                 281.0               LUNCH                 275.0
# 7                 281.0               NIGHT                 222.0
# 8                 281.0                 PIG                 233.0
# 9                 281.0                 SUN                 181.0
#
#    avg_age_acquisition  age_acquisition_diff  Word2Vec_similarity  \
# 4                292.0                  22.0             0.756927
# 6                278.0                   6.0             0.684256
# 7                251.5                  59.0             0.673507
# 8                257.0                  48.0             0.361940
# 9                231.0                 100.0             0.336822
#
#    association  concreteness_diff  concreteness_1  concreteness_2
# 4         17.0               33.0           406.0           439.0
# 6          2.0              146.0           406.0           552.0
# 7          3.0               90.0           406.0           496.0
# 8          2.0              208.0           406.0           614.0
# 9          2.0              211.0           406.0           617.0

# %%
df2.to_csv('updated_merged_data_without_count1.csv', index=False)
